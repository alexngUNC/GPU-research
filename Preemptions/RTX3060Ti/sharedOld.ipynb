# %% [markdown]
# # Shared Memory

# %%
from analyzer_functions import *
no_shared_path = '~/GPU-research/Preemptions/preemptions/times/shared/no_shared100.csv'
shared_path = '~/GPU-research/Preemptions/preemptions/times/shared/shared100.csv'
no_shared_sync_path = '~/GPU-research/Preemptions/preemptions/times/shared/no_sharedSync.csv'
shared_sync_path = '~/GPU-research/Preemptions/preemptions/times/shared/sharedSync.csv'
no_shared_sync_100k_path = '~/GPU-research/Preemptions/preemptions/times/shared/no_sharedSync100000.csv'
shared_sync_100k_path = '~/GPU-research/Preemptions/preemptions/times/shared/sharedSync100000.csv'



paths = [no_shared_path, shared_path, no_shared_sync_path, shared_sync_path, no_shared_sync_100k_path, shared_sync_100k_path]

ivls = read_ivls(paths, single=False)

# %%
TIMESLICE_LENGTH = 2131
NUM_SAMPLES = 100

plot_side_by_side(noSharedData=ivls[0], sharedData=ivls[1], NUM_SAMPLES=NUM_SAMPLES, lowerBound=TIMESLICE_LENGTH + 100, upperBound=TIMESLICE_LENGTH + 200,
                  medianLines=True, firstLabel="No shared", secondLabel="Shared", lowerTextOffset=1, upperTextOffset=10)

# %%
no_shared_oh = get_overhead(ivls[0], timeslice_length=TIMESLICE_LENGTH)
shared_oh = get_overhead(ivls[1], timeslice_length=TIMESLICE_LENGTH)
n = NUM_SAMPLES*2 - 2
plot_side_by_side(noSharedData=no_shared_oh, sharedData=shared_oh, NUM_SAMPLES=n, medianLines=True,
                  lowerBound=50, upperBound=100, firstLabel="No Shared", secondLabel="Shared", plotOverhead=True)

# %%
left_ivls = cut_ivls(no_shared_oh, [25, 75])
right_ivls = cut_ivls(shared_oh, [25, 75])
n = len(left_ivls)
plot_side_by_side(noSharedData=left_ivls, sharedData=right_ivls, NUM_SAMPLES=n, medianLines=True,
                 lowerBound=50, upperBound=100, firstLabel="No Shared", secondLabel="Shared", plotOverhead=True)

# %%
plot_side_by_side(noSharedData=ivls[2], sharedData=ivls[3], NUM_SAMPLES=NUM_SAMPLES, lowerBound=TIMESLICE_LENGTH + 100, upperBound=TIMESLICE_LENGTH + 200,
                  medianLines=True, firstLabel="No shared", secondLabel="Shared", lowerTextOffset=1, upperTextOffset=10)
no_shared_sync_oh = get_overhead(ivls[2], timeslice_length=TIMESLICE_LENGTH)
shared_sync_oh = get_overhead(ivls[3], timeslice_length=TIMESLICE_LENGTH)
n = NUM_SAMPLES * 2 - 2
plot_side_by_side(noSharedData=no_shared_sync_oh, sharedData=shared_sync_oh, NUM_SAMPLES=n, medianLines=True,
                  lowerBound=50, upperBound=100, firstLabel="No Shared", secondLabel="Shared", plotOverhead=True, oneSideTicks=True)

# %% [markdown]
# ## 100K Preemptions

# %%
TIMESLICE_LENGTH = 2131
NUM_SAMPLES = 100000
OFFSET = NUM_SAMPLES // 10
plot_side_by_side(noSharedData=ivls[4], sharedData=ivls[5], NUM_SAMPLES=NUM_SAMPLES, lowerBound=TIMESLICE_LENGTH + 100, upperBound=TIMESLICE_LENGTH + 200,
                  medianLines=True, firstLabel="No shared", secondLabel="Shared", lowerTextOffset=10, upperTextOffset=10, offset=OFFSET, thousand=True)
no_shared_sync_oh = get_overhead(ivls[4], timeslice_length=TIMESLICE_LENGTH)
shared_sync_oh = get_overhead(ivls[5], timeslice_length=TIMESLICE_LENGTH)
n = NUM_SAMPLES * 2 - 2
plot_side_by_side(noSharedData=no_shared_sync_oh, sharedData=shared_sync_oh, NUM_SAMPLES=n, medianLines=True, lowerTextOffset=10, upperTextOffset=10, offset=OFFSET,
                  lowerBound=50, upperBound=100, firstLabel="No Shared", secondLabel="Shared", plotOverhead=True, oneSideTicks=True, thousand=True)
