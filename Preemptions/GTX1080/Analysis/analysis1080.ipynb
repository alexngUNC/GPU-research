# %% [markdown]
# # GTX 1080 Shared Memory Comparison

# %%
# Import helper functions
# %cd ~/Desktop/Research/GPU-research/Preemptions
from analyzer_functions import *

# Load in the data
noSharedPath = 'GTX1080/Data/saxpyMillion1080.csv'
sharedPath = 'GTX1080/Data/saxpy1080OutsideLoop.csv' # 1080SharedCustom

noShared, shared, no_shared_ivls, shared_ivls = data_loader(noSharedPath=noSharedPath, sharedPath=sharedPath)
# Out:
# /Users/alexgeorgiev/Desktop/Research/GPU-research/Preemptions
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Plot on the same plot

# %%
same_plotter(noSharedData=no_shared_ivls, sharedData=shared_ivls, NUM_SAMPLES=1000000)

# %% [markdown]
# ### Zoom-in

# %%
same_plotter(noSharedData=no_shared_ivls, sharedData=shared_ivls, NUM_SAMPLES=1000000, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ## Plot separately

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared_ivls, NUM_SAMPLES=1000000)

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared_ivls, NUM_SAMPLES=1000000, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ## Loop after shared memory is saturated

# %%
# Load in the data
endLoopPath = 'GTX1080/Data/saxpyEndLoopShared.csv'
noShared, endShared, no_shared_ivls, end_shared_ivls = data_loader(noSharedPath=noSharedPath, sharedPath=endLoopPath)

# %% [markdown]
# ### Plot on the same plot

# %%
same_plotter(noSharedData=no_shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000)

# %% [markdown]
# ### Zoom-in

# %%
same_plotter(noSharedData=no_shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ### Plot separately

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000)

# %% [markdown]
# ### Zoom-in

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ## Compare Shared Loop Kernels

# %%
same_plotter(noSharedData=shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000, firstLabel='Array Inside Loop', secondLabel='Array Outside Loop')
plot_separate(noSharedData=shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000, firstLabel='Array Inside Loop', secondLabel='Array Outside Loop')

# %% [markdown]
# ### Zoom-in

# %%
same_plotter(noSharedData=no_shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000, lowerBound=2.2*1e6, upperBound=2.5*1e6, firstLabel='Array Inside Loop', secondLabel='Array Outside Loop')
plot_separate(noSharedData=shared_ivls, sharedData=end_shared_ivls, NUM_SAMPLES=1000000, lowerBound=2.2*1e6, upperBound=2.5*1e6, firstLabel='Array Inside Loop', secondLabel='Array Outside Loop')
