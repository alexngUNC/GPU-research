# %%
# Import helper functions
# %cd ~/Desktop/Research/GPU-research/Preemptions
from analyzer_functions import *

# Load in the data
noSharedPath = 'GTX1080/Data/saxpyMillion1080.csv'
shared100Path = 'GTX1080/Data/saxpy1080OutsideLoop.csv' # 1080SharedCustom
shared25Path = 'GTX1080/Data/saxpy108025P.csv'
shared50Path = 'GTX1080/Data/saxpy108050P.csv'
shared75Path = 'GTX1080/Data/saxpy108075P.csv'

noShared, shared100, no_shared_ivls, shared100_ivls = data_loader(noSharedPath=noSharedPath, sharedPath=shared100Path)
shared25, shared25_ivls = data_loader(single=True, singlePath=shared25Path)
shared50, shared50_ivls = data_loader(single=True, singlePath=shared50Path)
shared75, shared75_ivls = data_loader(single=True, singlePath=shared75Path)
# Out:
# /Users/alexgeorgiev/Desktop/Research/GPU-research/Preemptions
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## 25% Shared Memory Capacity

# %%
NUM_SAMPLES = 1000000
plot_separate(noSharedData=no_shared_ivls, sharedData=shared25_ivls, NUM_SAMPLES=NUM_SAMPLES)

# %%
NUM_SAMPLES = 1000000
plot_separate(noSharedData=no_shared_ivls, sharedData=shared25_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ## 50% Shared Memory Capacity

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared50_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ## 75% Shared Memory Capacity

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared75_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %% [markdown]
# ## 100% Shared Memory Capacity

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared100_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=2.2*1e6, upperBound=2.5*1e6)

# %%
import numpy as np
print(f'No Shared: {np.mean(no_shared_ivls)}\n25% Shared: {np.mean(shared25_ivls)}\n50% Shared: {np.mean(shared50_ivls)}\n75% Shared: {np.mean(shared75_ivls)}\n100% Shared: {np.mean(shared100_ivls)}')
# Out:
# No Shared: 2322090.148133148
# 25% Shared: 2348115.047764048
# 50% Shared: 2322172.7928287927
# 75% Shared: 2320687.1918101916
# 100% Shared: 2340180.9316079314

# %%
# n = 40960
# X = []
# Y = []
# for i in range(40960):
#   # X.append(i)
#   Y.append(i * 2)

# %%
# import numpy as np
# x = np.array(X)
# y = np.array(Y)
# Z = []
# j = 1
# while True:
#   y += 10 * x 
#   print(y[-1])
#   j+=1
