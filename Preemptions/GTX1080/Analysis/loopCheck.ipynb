# %% [markdown]
# # GTX 1080 Results

# %%
# %cd ~/Desktop/Research/GPU-research/Preemptions
# Out:
# /Users/alexgeorgiev/Desktop/Research/GPU-research/Preemptions

# %% [markdown]
# ## Check if having the array declaration outside the loop affects anything

# %% [markdown]
# Note: For this segment, "without shared memory" will refer to the shared memory kernel with the shared memory array declaration inside of the while loop.

# %%
# Import helper functions
from analyzer_functions import *

# Load the data
insideLoopPath = 'GTX1080/Data/saxpyMillion1080Shared.csv'
outsideLoopPath = 'GTX1080/Data/saxpy1080OutsideLoop.csv'

insideData, outsideData, insideIvls, outsideIvls = data_loader(insideLoopPath, outsideLoopPath)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Plot the data separately
plot_separately(insideIvls, outsideIvls, NUM_SAMPLES=len(insideData), lowerBound=2.3*1e6, upperBound=2.5*1e6)

# %% [markdown]
# Apparently putting the array outside of the loop doesn't affect it.
