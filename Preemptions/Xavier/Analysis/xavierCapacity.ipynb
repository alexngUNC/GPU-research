# %% [markdown]
# # Xavier Capacities

# %%
# Import helper functions
# %cd ~/Desktop/Research/GPU-research/Preemptions
from analyzer_functions import *

# Load in the data from saxpySharedCustom
noSharedPath = 'Xavier/Data/saxpyData/loopTests/saxpyMillion.csv'
shared100Path = 'Xavier/capacityData/xavierShared100P.csv'
shared100PathOld = 'Xavier/Data/realMaxData/saxpyMillionSharedReal.csv'
shared25Path = 'Xavier/capacityData/xavierShared25P.csv'
shared50Path = 'Xavier/capacityData/xavierShared50P.csv'
shared75Path = 'Xavier/capacityData/xavierShared75P.csv'

noShared, shared100, no_shared_ivls, shared100_ivls = data_loader(noSharedPath=noSharedPath, sharedPath=shared100Path)
shared100Old, shared100Old_ivls = data_loader(single=True, singlePath=shared100PathOld)
shared25, shared25_ivls = data_loader(single=True, singlePath=shared25Path)
shared50, shared50_ivls = data_loader(single=True, singlePath=shared50Path)
shared75, shared75_ivls = data_loader(single=True, singlePath=shared75Path)
# Out:
# /Users/alexgeorgiev/Desktop/Research/GPU-research/Preemptions
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Compare 100% Capacities

# %%
NUM_SAMPLES = 1000000
plot_separate(noSharedData=shared100Old_ivls, sharedData=shared100_ivls, NUM_SAMPLES=NUM_SAMPLES, firstLabel='Old 100% Shared', secondLabel='New 100% Shared', lowerBound=0, upperBound=2e6)

# %% [markdown]
# ### Zoom in

# %%
plot_separate(noSharedData=shared100Old_ivls, sharedData=shared100_ivls, NUM_SAMPLES=NUM_SAMPLES, firstLabel='Old 100% Shared', secondLabel='New 100% Shared', lowerBound=1.25e6, upperBound=1.35e6)

# %% [markdown]
# ## 25% Shared Memory

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared25_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=0, upperBound=2e6)

# %% [markdown]
# ### Zoom-in

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared25_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=1.25e6, upperBound=1.35e6)

# %% [markdown]
# ### Five Number Summary

# %%
sum_25 = five_number_summary(noSharedIvls=no_shared_ivls, sharedIvls=shared25_ivls)
# Out:
# No Shared Memory:
# -----------------
# Minimum: 5120.0
# Q1: 1297529.0
# Median: 1298553.0
# Q3: 1298553.0
# Maximum: 1939637.0
# -----------------
#
# Shared Memory:
# -----------------
# Minimum: 2048.0
# Q1: 1301620.0
# Median: 1302644.0
# Q3: 1303668.0
# Maximum: 1741979.0
# -----------------

# %% [markdown]
# ### Difference in Means

# %%
meanDiff25, meanPerc25 = mean_difference(noSharedIvls=no_shared_ivls, sharedIvls=shared25_ivls)
# Out:
# No Shared Memory Mean: 1297983.2245482246
# Shared Memory Mean: 1302396.3902163901
# -----------------
# Difference in Means: 4413.165668165544
# Percent Difference: 0.34000174922920046

# %% [markdown]
# ## 50% Shared Memory

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared50_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=1.25e6, upperBound=1.35e6)

# %% [markdown]
# ### Five Number Summary

# %%
sum_50 = five_number_summary(noSharedIvls=no_shared_ivls, sharedIvls=shared50_ivls)
# Out:
# No Shared Memory:
# -----------------
# Minimum: 5120.0
# Q1: 1297529.0
# Median: 1298553.0
# Q3: 1298553.0
# Maximum: 1939637.0
# -----------------
#
# Shared Memory:
# -----------------
# Minimum: 2048.0
# Q1: 1303661.0
# Median: 1304685.0
# Q3: 1305709.0
# Maximum: 2373830.0
# -----------------

# %% [markdown]
# ### Difference in Means

# %%
meanDiff50, meanPerc50 = mean_difference(noSharedIvls=no_shared_ivls, sharedIvls=shared50_ivls)
# Out:
# No Shared Memory Mean: 1297983.2245482246
# Shared Memory Mean: 1304683.6667896667
# -----------------
# Difference in Means: 6700.442241442157
# Percent Difference: 0.5162194791673297

# %% [markdown]
# ## 75% Shared Memory

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared75_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=1.25e6, upperBound=1.35e6)

# %% [markdown]
# ### Five Number Summary

# %%
sum_75 = five_number_summary(noSharedIvls=no_shared_ivls, sharedIvls=shared75_ivls)
# Out:
# No Shared Memory:
# -----------------
# Minimum: 5120.0
# Q1: 1297529.0
# Median: 1298553.0
# Q3: 1298553.0
# Maximum: 1939637.0
# -----------------
#
# Shared Memory:
# -----------------
# Minimum: 5121.0
# Q1: 1305759.0
# Median: 1305760.0
# Q3: 1307808.0
# Maximum: 1971441.0
# -----------------

# %% [markdown]
# ### Difference in Means

# %%
meanDiff75, meanPerc75 = mean_difference(noSharedIvls=no_shared_ivls, sharedIvls=shared75_ivls)
# Out:
# No Shared Memory Mean: 1297983.2245482246
# Shared Memory Mean: 1305967.7084297084
# -----------------
# Difference in Means: 7984.483881483786
# Percent Difference: 0.6151453832743379

# %% [markdown]
# ## 100% Shared Memory

# %%
plot_separate(noSharedData=no_shared_ivls, sharedData=shared100_ivls, NUM_SAMPLES=NUM_SAMPLES, lowerBound=1.25e6, upperBound=1.35e6)

# %% [markdown]
# ### Five Number Summary

# %%
sum_100 = five_number_summary(noSharedIvls=no_shared_ivls, sharedIvls=shared100_ivls)
# Out:
# No Shared Memory:
# -----------------
# Minimum: 5120.0
# Q1: 1297529.0
# Median: 1298553.0
# Q3: 1298553.0
# Maximum: 1939637.0
# -----------------
#
# Shared Memory:
# -----------------
# Minimum: 9217.0
# Q1: 1309821.0
# Median: 1310846.0
# Q3: 1311870.0
# Maximum: 1988799.0
# -----------------

# %% [markdown]
# ### Difference in Means

# %%
meanDiff100, meanPerc100 = mean_difference(noSharedIvls=no_shared_ivls, sharedIvls=shared100_ivls)
# Out:
# No Shared Memory Mean: 1297983.2245482246
# Shared Memory Mean: 1310466.3627563627
# -----------------
# Difference in Means: 12483.138208138058
# Percent Difference: 0.96173340086756

# %% [markdown]
# ## All Difference in Means

# %%
print(f"25% Shared Memory (ns): {meanDiff25}")
print(f"50% Shared Memory (ns): {meanDiff50}")
print(f"75% Shared Memory (ns): {meanDiff75}")
print(f"100% Shared Memory (ns): {meanDiff100}")
print("\n------------------------------------\n")
print(f"25% Shared Memory (us): {meanDiff25/1000}")
print(f"50% Shared Memory (us): {meanDiff50/1000}")
print(f"75% Shared Memory (us): {meanDiff75/1000}")
print(f"100% Shared Memory (us): {meanDiff100/1000}")
# Out:
# 25% Shared Memory (ns): 4413.165668165544
# 50% Shared Memory (ns): 6700.442241442157
# 75% Shared Memory (ns): 7984.483881483786
# 100% Shared Memory (ns): 12483.138208138058
#
# ------------------------------------
#
# 25% Shared Memory (us): 4.4131656681655445
# 50% Shared Memory (us): 6.700442241442157
# 75% Shared Memory (us): 7.9844838814837855
# 100% Shared Memory (us): 12.483138208138058

# %% [markdown]
# ## Percentage Difference in Means

# %%
print(f"25% Shared Memory: {meanPerc25}")
print(f"50% Shared Memory: {meanPerc50}")
print(f"75% Shared Memory: {meanPerc75}")
print(f"100% Shared Memory: {meanPerc100}")
# Out:
# 25% Shared Memory: 0.34000174922920046
# 50% Shared Memory: 0.5162194791673297
# 75% Shared Memory: 0.6151453832743379
# 100% Shared Memory: 0.96173340086756
